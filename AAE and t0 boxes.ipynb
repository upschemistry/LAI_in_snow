# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(9,6))
plt.xlim([3.5, 7.5])
plt.xlabel("$t_0 (s)$")
plt.ylim([-3.5, 5])
plt.ylabel("Å")
plt.grid(True)
alpha = 0.5

rect = Rectangle((3.95, 1.5), 2, 1.5, fill=True, color='red', alpha=alpha/2); ax.add_patch(rect)
plt.text(4.7, 2.1, 'igneous rock\n(literature)')

rect = Rectangle((4.9, 1.2), 2.0, 0.4, fill=True, color='blue', alpha=alpha/3); ax.add_patch(rect)
plt.text(5.5, 1.3, 'Rainier dirt')

rect = Rectangle((6.3, 3.4), 0.4, 0.9, fill=True, color='orange', alpha=alpha/2); ax.add_patch(rect)
plt.text(6.4,3.6,'pine \npollen')

# rect = Rectangle((4.2, 0.5), 0.3, 0.8, fill=True, color='black', alpha=alpha); ax.add_patch(rect)
# plt.text(4.1,0.3,'Rainier black')

rect = Rectangle((5.1, -3.0), 1.3, 4, fill=True, color='black', alpha=alpha/2); ax.add_patch(rect)
plt.text(5.2,-.6,'fullerene \n(std)')

MtRainierMuir_AAE = np.array([1.9, 1.7])
MtRainierMuir_t0 = np.array([7.1, 5.4]) 
plt.plot(MtRainierMuir_t0,MtRainierMuir_AAE,'go',label='Rainier (Muir)')

MtRainierSummit_AAE = np.array([.24, 1.4])
MtRainierSummit_t0 = np.array([5.4, 2.2])
plt.plot(MtRainierSummit_t0,MtRainierSummit_AAE,'bx',label='Rainier (summit)')

MtBakerSummit_AAE = np.array([2.1])
MtBakerSummit_t0 = np.array([5.0]) # June 25, 2025
plt.plot(MtBakerSummit_t0,MtBakerSummit_AAE,'gx',label='Baker (summit)')

MtRainierSite1surface_AAE = np.array([1.7,1.8])
MtRainierSite1surface_t0 = np.array([6.6,6.2]) # 1A, 1B
plt.scatter(MtRainierSite1surface_t0,MtRainierSite1surface_AAE, color='orange', marker = 's', label='Rainier (site 1, surface)')

MtRainierSite1subsurface_AAE = np.array([1.5, 1.8, 1.8, 1.6, 1.2]) 
MtRainierSite1subsurface_t0 = np.array( [4.4, 4.3, 4.3, 4.1, 4.4]) # 2A, 3A, 3A, 4A, 5A, 6A
plt.plot(MtRainierSite1subsurface_t0,MtRainierSite1subsurface_AAE,'ks',label='Rainier (site 1, subsurface)')

# For  1A.txt , L1 = 12.915022245559538 , L2 = 6.101350451309343 , AAE = 2.0861339572193147
# For  1B.txt , L1 = 7.561921849956911 , L2 = 4.213345587160997 , AAE = 1.5125401527429876
# For  2A.txt , L1 = 3.2622100921384183 , L2 = 2.407647266214585 , AAE = 0.5353729466392187
# For  3A.txt , L1 = 3.595493593808463 , L2 = 2.3915986798526845 , AAE = 0.8967592487129132
# For  4A.txt , L1 = 6.5234199728056375 , L2 = 3.8377460542548154 , AAE = 1.3235995729789831
# For  5A.txt , L1 = 6.595037458418671 , L2 = 4.0253941155365505 , AAE = 1.1956148793676367
# For  6.txt , L1 = 6.053614818592589 , L2 = 4.091851955283026 , AAE = 0.8409291451984089

# Rainier (UPS UPS UPS)/2025-07-03-01-1A/run_1.txt 11.399083409037805 455.96333636151223 6.587751356340592
# Rainier (UPS UPS UPS)/2025-07-03-01-1B/run_1.txt 9.729193919642071 389.16775678568285 6.181191755052315
# Rainier (UPS UPS UPS)/2025-07-03-01-1C/run_1.txt 9.640694715746102 321.3564905248701 6.4542401123224025
# Rainier (UPS UPS UPS)/2025-07-03-01-2A/run_1.txt 8.276143307353498 59.11530933823927 4.374409468746958
# Rainier (UPS UPS UPS)/2025-07-03-01-2B/run_1.txt 9.889393714096105 65.92929142730738 4.506789713116549
# Rainier (UPS UPS UPS)/2025-07-03-01-3A/run_1.txt 8.372626283495388 41.86313141747694 4.274289506382334
# Rainier (UPS UPS UPS)/2025-07-03-01-3B/run_1.txt 7.764258681639873 37.87443259336524 4.276612351992726
# Rainier (UPS UPS UPS)/2025-07-03-01-4A/run_1.txt 8.06248340589304 11.19789361929589 4.276471384607427
# Rainier (UPS UPS UPS)/2025-07-03-01-4B/run_1.txt 7.317985726099035 10.454265322998621 4.283317455278426
# Rainier (UPS UPS UPS)/2025-07-03-01-5A/run_1.txt 8.834798316308984 12.443377910294343 4.140303026734654
# Rainier (UPS UPS UPS)/2025-07-03-01-5B/run_1.txt 7.7297062201060065 11.5368749553821 4.289338108348625
# Rainier (UPS UPS UPS)/2025-07-03-01-6/run_1.txt 6.548085313264046 4.4243819684216525 4.384542400100235


# ax.legend(bbox_to_anchor=(1.2, 0.5))
plt.legend(loc='lower left')
