# %% [markdown]
# Definition of the absorption optical depth:
# $$
# \tau = log({I_0 \over I})
# $$
#
# Definition of the absorption Angstrom exponent:
# $$
# AAE = -{log(\tau_{450}/\tau_{600}) \over log(\lambda_{450}/\lambda_{600})}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import uniform_filter1d
import ISSWlib as IS

# %%
# %matplotlib notebook

# %%
pwd
# Out:
# '/home/chemistry/ISSW'

# %%
# Choose the spectrum folder and load in the list of spectra there
#spectrum_folder = 'Rainier_and_MtCook_comparison/'
# spectrum_folder = 'UPS_Rainier2025-07-03-01/'
# spectrum_folder = '2016Chile/'
# spectrum_folder = 'UCBoulder_Rainier/'
spectrum_folder = 'UCBoulder_Baker/'
# spectrum_folder = 'UCBoulder_Adams/'
# spectrum_folder = 'UCBoulder_Misc/'
# spectrum_folder = 'UPS_INKStandards/'
# spectrum_folder = 'NuCStandards/'
spectrum_filelist = spectrum_folder+'spectrum_files.txt'
spectrum_list, number = IS.get_spectrum_list(spectrum_filelist)

# Load in the blank, and check indices
lambda_nm, I0_offset = IS.get_spectrum(spectrum_folder+'/Blank.txt')
I_450 = 100; print('lambda_450 = ',lambda_nm[I_450])
I_500 = 150; print('lambda_500 = ',lambda_nm[I_500])
I_600 = 250; print('lambda_600 = ',lambda_nm[I_600])
I_1 = I_450
I_2 = I_600

for i in range(number):
    
    # Extract the spectrum for this item in the list
    spectrum_filename = spectrum_list[i]
    lambda_nm, I_offset = IS.get_spectrum(spectrum_folder+spectrum_filename)
    
    # Get and record the Anstrom Exponent
    AAE,Ismooth,tau = IS.getAngstromExponent(
                I_offset,I0_offset,lambda_nm, title=spectrum_filename, 
                I_1 = I_1, I_2 = I_2,
                verbose = True)
#     AAElist = np.append(AAElist,AAE)
    if i==0:
        AAElist = AAE
        Ismoothlist = Ismooth
        taulist = tau
    else:
        AAElist = np.append(AAElist,AAE)
        Ismoothlist = np.vstack((Ismoothlist,Ismooth))
        taulist = np.vstack((taulist,tau))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 12>()
#       7 # spectrum_folder = 'UCBoulder_Adams/'
#       8 # spectrum_folder = 'UCBoulder_Misc/'
#       9 # spectrum_folder = 'UPS_INKStandards/'
#      10 # spectrum_folder = 'NuCStandards/'
#      11 spectrum_filelist = spectrum_folder+'spectrum_files.txt'
# ---> 12 spectrum_list, number = IS.get_spectrum_list(spectrum_filelist)
#      14 # Load in the blank, and check indices
#      15 lambda_nm, I0_offset = IS.get_spectrum(spectrum_folder+'/Blank.txt')
#
# NameError: name 'IS' is not defined

# %%
# Plotting to visualize the AAE values as slopes in this space
plt.figure()
for i in range(number):
    tau_normalized = taulist[i]/taulist[i][I_1]
    plt.loglog(lambda_nm[I_1],tau_normalized[I_1],'ko')
    plt.loglog(lambda_nm[I_2],tau_normalized[I_2],'ko')
    plt.loglog(lambda_nm,tau_normalized,label=spectrum_list[i])
    plt.xlabel('wavelength (nm)')
    plt.ylabel('optical depth, tau')
    plt.xlim([400,750])
    plt.ylim([0.5,1.1])
    plt.title('All spectra (normalized)')
    plt.grid(True)
    plt.legend()

for i in range(number):
    print('For ',spectrum_list[i],', AAE =', AAElist[i])
# Out:
# <img src="data:image/png;base64,..." width="640.2">
# For  A.14mL.txt , AAE = 0.9289031018608841
# For  C.20mL.txt , AAE = 0.4311977233420549
# For  B.10mL.txt , AAE = 1.21198009221048
# For  C.34mL.txt , AAE = 0.23478108636672368
# For  C.50mL.txt , AAE = 0.16797789839424992
# For  C.57mL.txt , AAE = 0.2838445269488611
